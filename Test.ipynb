# %% [markdown]
# <a href="https://colab.research.google.com/github/eUbaagRii/nm/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3,14
a
# Out:
# (3, 14)

# %%
b = 7,3
print(b)
a
# Out:
# (7, 3)
# (3, 14)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
